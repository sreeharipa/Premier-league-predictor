# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("csvs/s4.csv")

# %%
df.HomeTeam.value_counts()
# Out:
# Burnley           19
# Liverpool         19
# Southampton       19
# Newcastle         19
# Crystal Palace    19
# Man United        19
# West Brom         19
# Tottenham         19
# Everton           19
# Stoke             19
# Brighton          19
# Swansea           19
# Bournemouth       19
# Chelsea           19
# Huddersfield      19
# West Ham          19
# Arsenal           19
# Man City          19
# Watford           19
# Leicester         19
# Name: HomeTeam, dtype: int64

# %%
#pd.options.display.max_columns = None
#pd.options.display.max_rows = None

# %%
df.columns
# Out:
# Index(['Div', 'Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HTHG',
#        'HTAG', 'HTR', 'Referee', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC',
#        'AC', 'HY', 'AY', 'HR', 'AR', 'B365H', 'B365D', 'B365A', 'BWH', 'BWD',
#        'BWA', 'IWH', 'IWD', 'IWA', 'LBH', 'LBD', 'LBA', 'PSH', 'PSD', 'PSA',
#        'WHH', 'WHD', 'WHA', 'VCH', 'VCD', 'VCA', 'Bb1X2', 'BbMxH', 'BbAvH',
#        'BbMxD', 'BbAvD', 'BbMxA', 'BbAvA', 'BbOU', 'BbMx>2.5', 'BbAv>2.5',
#        'BbMx<2.5', 'BbAv<2.5', 'BbAH', 'BbAHh', 'BbMxAHH', 'BbAvAHH',
#        'BbMxAHA', 'BbAvAHA', 'PSCH', 'PSCD', 'PSCA'],
#       dtype='object')

# %%
df.head(1)
# Out:
#   Div        Date HomeTeam   AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR Referee  \
# 0  E0  11/08/2017  Arsenal  Leicester     4     3   H     2     2   D  M Dean
#
#    HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR  B365H  B365D  B365A  BWH  \
# 0  27   6   10    3   9  12   9   4   0   1   0   0   1.53    4.5    6.5  1.5
#
#    BWD   BWA   IWH  IWD  IWA   LBH  LBD  LBA   PSH   PSD   PSA   WHH  WHD  \
# 0  4.6  6.75  1.47  4.5  6.5  1.44  4.4  6.5  1.53  4.55  6.85  1.53  4.2
#
#    WHA   VCH  VCD  VCA  Bb1X2  BbMxH  BbAvH  BbMxD  BbAvD  BbMxA  BbAvA  BbOU  \
# 0  6.0  1.53  4.5  6.5     41   1.55   1.51    4.6   4.43   6.89   6.44    37
#
#    BbMx>2.5  BbAv>2.5  BbMx<2.5  BbAv<2.5  BbAH  BbAHh  BbMxAHH  BbAvAHH  \
# 0      1.65      1.61      2.43      2.32    21   -1.0     1.91     1.85
#
#    BbMxAHA  BbAvAHA  PSCH  PSCD  PSCA
# 0      2.1     2.02  1.49  4.73  7.25

# %%
df = df.drop(['Div'], axis = 1)

# %%
df.head(1)
# Out:
#          Date HomeTeam   AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR Referee  HS  \
# 0  11/08/2017  Arsenal  Leicester     4     3   H     2     2   D  M Dean  27
#
#    AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR  B365H  B365D  B365A  BWH  \
# 0   6   10    3   9  12   9   4   0   1   0   0   1.53    4.5    6.5  1.5
#
#    BWD   BWA   IWH  IWD  IWA   LBH  LBD  LBA   PSH   PSD   PSA   WHH  WHD  \
# 0  4.6  6.75  1.47  4.5  6.5  1.44  4.4  6.5  1.53  4.55  6.85  1.53  4.2
#
#    WHA   VCH  VCD  VCA  Bb1X2  BbMxH  BbAvH  BbMxD  BbAvD  BbMxA  BbAvA  BbOU  \
# 0  6.0  1.53  4.5  6.5     41   1.55   1.51    4.6   4.43   6.89   6.44    37
#
#    BbMx>2.5  BbAv>2.5  BbMx<2.5  BbAv<2.5  BbAH  BbAHh  BbMxAHH  BbAvAHH  \
# 0      1.65      1.61      2.43      2.32    21   -1.0     1.91     1.85
#
#    BbMxAHA  BbAvAHA  PSCH  PSCD  PSCA
# 0      2.1     2.02  1.49  4.73  7.25

# %%
df.drop(df.columns[31:34], axis = 1, inplace = True)

# %%
df.head(1)
# Out:
#          Date HomeTeam   AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR Referee  HS  \
# 0  11/08/2017  Arsenal  Leicester     4     3   H     2     2   D  M Dean  27
#
#    AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR  B365H  B365D  B365A  BWH  \
# 0   6   10    3   9  12   9   4   0   1   0   0   1.53    4.5    6.5  1.5
#
#    BWD   BWA   IWH  IWD  IWA   PSH   PSD   PSA   WHH  WHD  WHA   VCH  VCD  \
# 0  4.6  6.75  1.47  4.5  6.5  1.53  4.55  6.85  1.53  4.2  6.0  1.53  4.5
#
#    VCA  Bb1X2  BbMxH  BbAvH  BbMxD  BbAvD  BbMxA  BbAvA  BbOU  BbMx>2.5  \
# 0  6.5     41   1.55   1.51    4.6   4.43   6.89   6.44    37      1.65
#
#    BbAv>2.5  BbMx<2.5  BbAv<2.5  BbAH  BbAHh  BbMxAHH  BbAvAHH  BbMxAHA  \
# 0      1.61      2.43      2.32    21   -1.0     1.91     1.85      2.1
#
#    BbAvAHA  PSCH  PSCD  PSCA
# 0     2.02  1.49  4.73  7.25

# %%
df.drop(df.columns[40:], axis = 1, inplace = True)

# %%
df.head(1)
# Out:
#          Date HomeTeam   AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR Referee  HS  \
# 0  11/08/2017  Arsenal  Leicester     4     3   H     2     2   D  M Dean  27
#
#    AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR  B365H  B365D  B365A  BWH  \
# 0   6   10    3   9  12   9   4   0   1   0   0   1.53    4.5    6.5  1.5
#
#    BWD   BWA   IWH  IWD  IWA   PSH   PSD   PSA   WHH  WHD  WHA   VCH  VCD  VCA
# 0  4.6  6.75  1.47  4.5  6.5  1.53  4.55  6.85  1.53  4.2  6.0  1.53  4.5  6.5

# %%
df.isnull().any()
# Out:
# Date        False
# HomeTeam    False
# AwayTeam    False
# FTHG        False
# FTAG        False
# FTR         False
# HTHG        False
# HTAG        False
# HTR         False
# Referee     False
# HS          False
# AS          False
# HST         False
# AST         False
# HF          False
# AF          False
# HC          False
# AC          False
# HY          False
# AY          False
# HR          False
# AR          False
# B365H       False
# B365D       False
# B365A       False
# BWH         False
# BWD         False
# BWA         False
# IWH         False
# IWD         False
# IWA         False
# PSH         False
# PSD         False
# PSA         False
# WHH         False
# WHD         False
# WHA         False
# VCH         False
# VCD         False
# VCA         False
# dtype: bool

# %%
df.shape
# Out:
# (380, 40)

# %%
df.to_csv('csvs/s4f.csv', index = False)

# %%
df = pd.read_csv("csvs/s3.csv")

# %%
df.shape
# Out:
# (380, 62)

# %%
df.drop(['Div'], axis = 1, inplace = True)

# %%
df.head(1)
# Out:
#          Date    HomeTeam   AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 0  10/08/2018  Man United  Leicester     2     1   H     1     0   H
#
#       Referee  HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR  B365H  B365D  \
# 0  A Marriner   8  13    6    4  11   8   2   5   2   1   0   0   1.57    3.9
#
#    B365A   BWH  BWD  BWA   IWH  IWD  IWA   PSH   PSD  PSA   WHH  WHD  WHA  \
# 0    7.5  1.53  4.0  7.5  1.55  3.8  7.0  1.58  3.93  7.5  1.57  3.8  6.0
#
#     VCH  VCD  VCA  Bb1X2  BbMxH  BbAvH  BbMxD  BbAvD  BbMxA  BbAvA  BbOU  \
# 0  1.57  4.0  7.0     39    1.6   1.56    4.2   3.92   8.05   7.06    38
#
#    BbMx>2.5  BbAv>2.5  BbMx<2.5  BbAv<2.5  BbAH  BbAHh  BbMxAHH  BbAvAHH  \
# 0      2.12      2.03      1.85      1.79    17  -0.75     1.75      1.7
#
#    BbMxAHA  BbAvAHA  PSCH  PSCD  PSCA
# 0     2.29     2.21  1.55  4.07  7.69

# %%
df.drop(df.columns[40:], axis = 1, inplace = True)

# %%
df.head(1)
# Out:
#          Date    HomeTeam   AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 0  10/08/2018  Man United  Leicester     2     1   H     1     0   H
#
#       Referee  HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR  B365H  B365D  \
# 0  A Marriner   8  13    6    4  11   8   2   5   2   1   0   0   1.57    3.9
#
#    B365A   BWH  BWD  BWA   IWH  IWD  IWA   PSH   PSD  PSA   WHH  WHD  WHA  \
# 0    7.5  1.53  4.0  7.5  1.55  3.8  7.0  1.58  3.93  7.5  1.57  3.8  6.0
#
#     VCH  VCD  VCA
# 0  1.57  4.0  7.0

# %%
df.shape
# Out:
# (380, 40)

# %%
df.to_csv('csvs/s3f.csv', index = False)

# %%
df = pd.read_csv("csvs/s2.csv")

# %%
df.shape
# Out:
# (380, 106)

# %%
df.head(1)
# Out:
#   Div        Date   Time   HomeTeam AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 0  E0  09/08/2019  20:00  Liverpool  Norwich     4     1   H     4     0   H
#
#     Referee  HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR  B365H  B365D  \
# 0  M Oliver  15  12    7    5   9   9  11   2   0   2   0   0   1.14   10.0
#
#    B365A   BWH   BWD   BWA   IWH  IWD   IWA   PSH   PSD    PSA   WHH  WHD  \
# 0   19.0  1.14  8.25  18.5  1.15  8.0  18.0  1.15  9.59  18.05  1.12  8.5
#
#     WHA   VCH  VCD   VCA  MaxH  MaxD  MaxA  AvgH  AvgD   AvgA  B365>2.5  \
# 0  21.0  1.14  9.5  23.0  1.16  10.0  23.0  1.14  8.75  19.83       1.4
#
#    B365<2.5  P>2.5  P<2.5  Max>2.5  Max<2.5  Avg>2.5  Avg<2.5   AHh  B365AHH  \
# 0       3.0    1.4   3.11     1.45     3.11     1.41     2.92 -2.25     1.96
#
#    B365AHA  PAHH  PAHA  MaxAHH  MaxAHA  AvgAHH  AvgAHA  B365CH  B365CD  \
# 0     1.94  1.97  1.95    1.97     2.0    1.94    1.94    1.14     9.5
#
#    B365CA  BWCH  BWCD  BWCA  IWCH  IWCD  IWCA  PSCH   PSCD   PSCA  WHCH  WHCD  \
# 0    21.0  1.14   9.0  20.0  1.15   8.0  18.0  1.14  10.43  19.63  1.11   9.5
#
#    WHCA  VCCH  VCCD  VCCA  MaxCH  MaxCD  MaxCA  AvgCH  AvgCD  AvgCA  \
# 0  21.0  1.14   9.5  23.0   1.16   10.5   23.0   1.14   9.52  19.18
#
#    B365C>2.5  B365C<2.5  PC>2.5  PC<2.5  MaxC>2.5  MaxC<2.5  AvgC>2.5  \
# 0        1.3        3.5    1.34    3.44      1.36      3.76      1.32
#
#    AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  MaxCAHA  \
# 0      3.43 -2.25      1.91      1.99   1.94   1.98     1.99     2.07
#
#    AvgCAHH  AvgCAHA
# 0      1.9     1.99

# %%
df.drop(['Div', 'Time'], axis = 1, inplace = True)

# %%
df.head(1)
# Out:
#          Date   HomeTeam AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR   Referee  \
# 0  09/08/2019  Liverpool  Norwich     4     1   H     4     0   H  M Oliver
#
#    HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR  B365H  B365D  B365A  \
# 0  15  12    7    5   9   9  11   2   0   2   0   0   1.14   10.0   19.0
#
#     BWH   BWD   BWA   IWH  IWD   IWA   PSH   PSD    PSA   WHH  WHD   WHA  \
# 0  1.14  8.25  18.5  1.15  8.0  18.0  1.15  9.59  18.05  1.12  8.5  21.0
#
#     VCH  VCD   VCA  MaxH  MaxD  MaxA  AvgH  AvgD   AvgA  B365>2.5  B365<2.5  \
# 0  1.14  9.5  23.0  1.16  10.0  23.0  1.14  8.75  19.83       1.4       3.0
#
#    P>2.5  P<2.5  Max>2.5  Max<2.5  Avg>2.5  Avg<2.5   AHh  B365AHH  B365AHA  \
# 0    1.4   3.11     1.45     3.11     1.41     2.92 -2.25     1.96     1.94
#
#    PAHH  PAHA  MaxAHH  MaxAHA  AvgAHH  AvgAHA  B365CH  B365CD  B365CA  BWCH  \
# 0  1.97  1.95    1.97     2.0    1.94    1.94    1.14     9.5    21.0  1.14
#
#    BWCD  BWCA  IWCH  IWCD  IWCA  PSCH   PSCD   PSCA  WHCH  WHCD  WHCA  VCCH  \
# 0   9.0  20.0  1.15   8.0  18.0  1.14  10.43  19.63  1.11   9.5  21.0  1.14
#
#    VCCD  VCCA  MaxCH  MaxCD  MaxCA  AvgCH  AvgCD  AvgCA  B365C>2.5  B365C<2.5  \
# 0   9.5  23.0   1.16   10.5   23.0   1.14   9.52  19.18        1.3        3.5
#
#    PC>2.5  PC<2.5  MaxC>2.5  MaxC<2.5  AvgC>2.5  AvgC<2.5  AHCh  B365CAHH  \
# 0    1.34    3.44      1.36      3.76      1.32      3.43 -2.25      1.91
#
#    B365CAHA  PCAHH  PCAHA  MaxCAHH  MaxCAHA  AvgCAHH  AvgCAHA
# 0      1.99   1.94   1.98     1.99     2.07      1.9     1.99

# %%
df.drop(df.columns[40:], axis = 1, inplace = True)

# %%
df.head(1)
# Out:
#          Date   HomeTeam AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR   Referee  \
# 0  09/08/2019  Liverpool  Norwich     4     1   H     4     0   H  M Oliver
#
#    HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR  B365H  B365D  B365A  \
# 0  15  12    7    5   9   9  11   2   0   2   0   0   1.14   10.0   19.0
#
#     BWH   BWD   BWA   IWH  IWD   IWA   PSH   PSD    PSA   WHH  WHD   WHA  \
# 0  1.14  8.25  18.5  1.15  8.0  18.0  1.15  9.59  18.05  1.12  8.5  21.0
#
#     VCH  VCD   VCA
# 0  1.14  9.5  23.0

# %%
df.shape
# Out:
# (380, 40)

# %%
df.to_csv('csvs/s2f.csv', index = False)

# %%
df = pd.read_csv("csvs/s1.csv")

# %%
df.shape
# Out:
# (380, 106)

# %%
df.head(1)
# Out:
#   Div        Date   Time HomeTeam AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 0  E0  12/09/2020  12:30   Fulham  Arsenal     0     3   A     0     1   A
#
#       Referee  HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR  B365H  B365D  \
# 0  C Kavanagh   5  13    2    6  12  12   2   3   2   2   0   0    6.0   4.33
#
#    B365A  BWH   BWD   BWA  IWH  IWD   IWA   PSH   PSD   PSA  WHH  WHD   WHA  \
# 0   1.53  5.5  4.25  1.57  6.0  3.9  1.57  6.16  4.51  1.56  6.5  4.2  1.53
#
#    VCH  VCD   VCA  MaxH  MaxD  MaxA  AvgH  AvgD  AvgA  B365>2.5  B365<2.5  \
# 0  6.5  4.2  1.55  6.55  4.55   1.6  5.94  4.34  1.55      1.72       2.1
#
#    P>2.5  P<2.5  Max>2.5  Max<2.5  Avg>2.5  Avg<2.5  AHh  B365AHH  B365AHA  \
# 0    1.8   2.13     1.84     2.18     1.76      2.1  1.0     1.93     1.97
#
#    PAHH  PAHA  MaxAHH  MaxAHA  AvgAHH  AvgAHA  B365CH  B365CD  B365CA  BWCH  \
# 0  1.96  1.96     2.0    1.99    1.93    1.95     5.0     4.0    1.66   5.5
#
#    BWCD  BWCA  IWCH  IWCD  IWCA  PSCH  PSCD  PSCA  WHCH  WHCD  WHCA  VCCH  \
# 0   4.0  1.62  5.25   3.9  1.67  5.48  3.98  1.69   5.5   3.8  1.65   5.5
#
#    VCCD  VCCA  MaxCH  MaxCD  MaxCA  AvgCH  AvgCD  AvgCA  B365C>2.5  B365C<2.5  \
# 0   3.9  1.67   5.75    4.2   1.71   5.36   3.93   1.67        2.0        1.8
#
#    PC>2.5  PC<2.5  MaxC>2.5  MaxC<2.5  AvgC>2.5  AvgC<2.5  AHCh  B365CAHH  \
# 0    2.06    1.86       2.1      1.92       2.0      1.84  0.75      2.01
#
#    B365CAHA  PCAHH  PCAHA  MaxCAHH  MaxCAHA  AvgCAHH  AvgCAHA
# 0      1.89   2.02   1.91     2.13     1.92     2.02     1.87

# %%
df.drop(['Div', 'Time'], axis = 1, inplace = True)

# %%
df.head(1)
# Out:
#          Date HomeTeam AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR     Referee  \
# 0  12/09/2020   Fulham  Arsenal     0     3   A     0     1   A  C Kavanagh
#
#    HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR  B365H  B365D  B365A  BWH  \
# 0   5  13    2    6  12  12   2   3   2   2   0   0    6.0   4.33   1.53  5.5
#
#     BWD   BWA  IWH  IWD   IWA   PSH   PSD   PSA  WHH  WHD   WHA  VCH  VCD  \
# 0  4.25  1.57  6.0  3.9  1.57  6.16  4.51  1.56  6.5  4.2  1.53  6.5  4.2
#
#     VCA  MaxH  MaxD  MaxA  AvgH  AvgD  AvgA  B365>2.5  B365<2.5  P>2.5  P<2.5  \
# 0  1.55  6.55  4.55   1.6  5.94  4.34  1.55      1.72       2.1    1.8   2.13
#
#    Max>2.5  Max<2.5  Avg>2.5  Avg<2.5  AHh  B365AHH  B365AHA  PAHH  PAHA  \
# 0     1.84     2.18     1.76      2.1  1.0     1.93     1.97  1.96  1.96
#
#    MaxAHH  MaxAHA  AvgAHH  AvgAHA  B365CH  B365CD  B365CA  BWCH  BWCD  BWCA  \
# 0     2.0    1.99    1.93    1.95     5.0     4.0    1.66   5.5   4.0  1.62
#
#    IWCH  IWCD  IWCA  PSCH  PSCD  PSCA  WHCH  WHCD  WHCA  VCCH  VCCD  VCCA  \
# 0  5.25   3.9  1.67  5.48  3.98  1.69   5.5   3.8  1.65   5.5   3.9  1.67
#
#    MaxCH  MaxCD  MaxCA  AvgCH  AvgCD  AvgCA  B365C>2.5  B365C<2.5  PC>2.5  \
# 0   5.75    4.2   1.71   5.36   3.93   1.67        2.0        1.8    2.06
#
#    PC<2.5  MaxC>2.5  MaxC<2.5  AvgC>2.5  AvgC<2.5  AHCh  B365CAHH  B365CAHA  \
# 0    1.86       2.1      1.92       2.0      1.84  0.75      2.01      1.89
#
#    PCAHH  PCAHA  MaxCAHH  MaxCAHA  AvgCAHH  AvgCAHA
# 0   2.02   1.91     2.13     1.92     2.02     1.87

# %%
df.drop(df.columns[40:], axis = 1, inplace = True)

# %%
df.head(1)
# Out:
#          Date HomeTeam AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR     Referee  \
# 0  12/09/2020   Fulham  Arsenal     0     3   A     0     1   A  C Kavanagh
#
#    HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR  B365H  B365D  B365A  BWH  \
# 0   5  13    2    6  12  12   2   3   2   2   0   0    6.0   4.33   1.53  5.5
#
#     BWD   BWA  IWH  IWD   IWA   PSH   PSD   PSA  WHH  WHD   WHA  VCH  VCD  \
# 0  4.25  1.57  6.0  3.9  1.57  6.16  4.51  1.56  6.5  4.2  1.53  6.5  4.2
#
#     VCA
# 0  1.55

# %%
df.shape
# Out:
# (380, 40)

# %%
df.to_csv('csvs/s1f.csv', index = False)

# %%
df = pd.concat(map(pd.read_csv, ['csvs/s1f.csv', 'csvs/s2f.csv', 'csvs/s3f.csv', 'csvs/s4f.csv']), ignore_index = True)

# %%
df.shape
# Out:
# (1520, 40)

# %%
df.to_csv('csvs/final.csv', index = False)
